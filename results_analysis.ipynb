# %%
import pandas as pd

# %%
res_file = 'results_log_regression.csv'
df = pd.read_csv(res_file)
df.sort_values(by=['f1_macro'], inplace=True, ascending=False)
df.head()
# Out:
#     scaling imputation  cat_age  target_freq  accuracy  f1_macro
# 2  standard       mode    False         0.90  0.947840  0.771625  \
# 4       NaN       mode    False         0.85  0.947553  0.771204
# 3       NaN       mode    False         0.80  0.940401  0.769298
# 1  standard       mode    False         0.85  0.938138  0.768753
# 5       NaN       mode    False         0.90  0.951814  0.758184
#
#    precision_macro  recall_macro
# 2         0.781386      0.762728
# 4         0.779860      0.763276
# 3         0.748647      0.794914
# 1         0.741711      0.805100
# 5         0.819959      0.718805

# %%
res_file = 'results_rf.csv'
df = pd.read_csv(res_file)
df.sort_values(by=['f1_macro'], inplace=True, ascending=False)
df.head()
# Out:
#      scaling imputation  cat_age  target_freq  accuracy  f1_macro
# 1        NaN       mode    False          0.8  0.939921  0.769267  \
# 7     minmax       mode    False          0.8  0.939828  0.769116
# 4        NaN      nacat    False          0.8  0.939355  0.768438
# 10    minmax      nacat    False          0.8  0.939212  0.768196
# 14  standard       mode    False          0.9  0.948226  0.763219
#
#     precision_macro  recall_macro
# 1          0.747061      0.797305
# 7          0.746753      0.797415
# 4          0.745231      0.798169
# 10         0.744765      0.798304
# 14         0.786927      0.743957
