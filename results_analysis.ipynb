# %%
import pandas as pd

# %%
res_file = 'results_log_regression.csv'
df = pd.read_csv(res_file)

# %%
# sort df by accuracy
df.sort_values(by=['f1_macro'], inplace=True, ascending=False)
df.head(10)
# Out:
#      scaling imputation  cat_age  target_freq  accuracy  f1_macro
# 15  standard     nancat    False          0.9  0.947854  0.771662  \
# 11  standard       mode    False          0.9  0.947840  0.771625
# 16       NaN       mode     True          0.8  0.940794  0.771155
# 20       NaN     nancat     True          0.8  0.940730  0.770962
# 9   standard       mode     True          0.9  0.949616  0.770868
# 13  standard     nancat     True          0.9  0.949544  0.770490
# 18       NaN       mode    False          0.8  0.940401  0.769298
# 22       NaN     nancat    False          0.8  0.940343  0.769143
# 0     minmax       mode     True          0.8  0.939985  0.768320
# 4     minmax     nancat     True          0.8  0.939921  0.768039
#
#     precision_macro  recall_macro
# 15         0.781459      0.762735
# 11         0.781386      0.762728
# 16         0.750062      0.797400
# 20         0.749830      0.797261
# 9          0.793053      0.752394
# 13         0.792730      0.751986
# 18         0.748647      0.794914
# 22         0.748454      0.794829
# 0          0.747193      0.794688
# 4          0.746962      0.794338
