# %%
import pandas as pd

# %%
df = pd.read_csv('results_log_regression.csv')
df.sort_values(by=['f1_macro'], inplace=True, ascending=False)
df.head()
# Out:
#     scaling imputation  cat_age  target_freq  accuracy  f1_macro  \
# 2  standard       mode    False         0.90  0.947840  0.771625
# 4       NaN       mode    False         0.85  0.947553  0.771204
# 3       NaN       mode    False         0.80  0.940401  0.769298
# 1  standard       mode    False         0.85  0.938138  0.768753
# 5       NaN       mode    False         0.90  0.951814  0.758184
#
#    precision_macro  recall_macro
# 2         0.781386      0.762728
# 4         0.779860      0.763276
# 3         0.748647      0.794914
# 1         0.741711      0.805100
# 5         0.819959      0.718805

# %%
df = pd.read_csv('results_rf.csv')
df.sort_values(by=['f1_macro'], inplace=True, ascending=False)
df.head()
# Out:
#     scaling imputation  cat_age  target_freq  accuracy  f1_macro  \
# 7       NaN     nancat    False          0.9  0.951169  0.771126
# 1       NaN       mode    False          0.9  0.950947  0.769860
# 4       NaN       mode     True          0.9  0.950704  0.768292
# 10      NaN     nancat     True          0.9  0.950525  0.768155
# 2       NaN       mode    False          1.0  0.952888  0.760241
#
#     precision_macro  recall_macro
# 7          0.804660      0.745338
# 1          0.803600      0.744000
# 4          0.802591      0.742121
# 10         0.801211      0.742716
# 2          0.829839      0.717703
